# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.style.use(["dark_background"])
plt.rcParams['figure.figsize'] = 10.0,8.0
font = {'family' : 'Sans',
        'weight' : 'normal',
        'size'   :18}
plt.rc("font",**font)

plt.rcParams.update({"grid.alpha":0.2})

# %%
dr = ["DR1","DR2","EDR3"]

# %%
plt.plot(dr,[1142679769/1e6,1692919135/1e6,1811709771/1e6],"o-",lw=5,
         markerfacecolor="black",markersize=14,markeredgewidth=4,color="red",
         label="Total de objetos")
plt.plot(dr,[2057050/1e6,1331909727/1e6,(585416709+882328109)/1e6],"o-",lw=5,
         markerfacecolor="black",markersize=14,markeredgewidth=4,color="#3fa69a",
         label="Obj. con 6 dimensiones")
plt.plot(dr,[1140622719/1e6,361009408/1e6,343964953/1e6],"o-",lw=5,
        markerfacecolor="black",markersize=14,markeredgewidth=4,
         label="Obj. con sólo posición",color="yellow")

plt.ylabel("Millones de objetos")
plt.legend()
plt.show()

# %%
plt.plot(dr,[2191/1e6,7224631/1e6,7209831/1e6],"o-",color="#3fa69a",
         label="Objetos con velocidad radial",lw=5,markeredgecolor="#3fa69a",
        markerfacecolor="black",markersize=14,markeredgewidth=4)

plt.ylabel("Millones de objetos")
plt.legend()
plt.show()
